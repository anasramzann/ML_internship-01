# %% [markdown]
# <a href="https://colab.research.google.com/github/anasramzann/ML_internship-01/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/anasramzann/ML_internship-01/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
#
# My Lane is User Engagemnent Analysis
# I choose it because our SEO metrics tell only half story and we need to understand how the viewer take our content we have to learn human intrest and the things from which they ignore our work

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
# QUestion :Which specific signals are engaged human interaction
#
# Analysis Unit : single page or URL
#
# Action: content writer have to assume that how they make articles more interactive or rewrite bored sections
#
# wrong call cost: misinterpret data take days to change elements that users attract
#
# ML Helps: A simple average cant tell us how diffrent pages make engaging page but ML helps to find hidden behaviour in data

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd
df=pd.read_csv('content_refresh_anonymized.csv')
print("Average Scroll Rate:",df['scroll_rate'].mean().round(2))
print("Average Engagement Rate:",df['engagement_rate'].mean().round(2))
# Out:
# Average Scroll Rate: 18.21
# Average Engagement Rate: 2.53

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
# What I claim:
# Based on starter data, we observe the baseline averages of how long users stay on page and scroll rate
#
#
# What I cant claim:
# We cant claim that a low scroll rate is always the writers fault it will be due to a technical issue slow loading speed, or bad mobile

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
